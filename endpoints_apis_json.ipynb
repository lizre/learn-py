# %% [markdown]
# # You use an _endpoint_ to make _request_s of an API resource

# %% [markdown]
# ie, endpoints _expose_ API resources
#
# ex: if we send this request to the github API endpoint:

# %%
# !curl -s https://api.github.com/users/lizre | head -n 3
# Out:
# {
#   "login": "lizre",
#   "id": 38010821,

# %% [markdown]
# (`-s` makes curl `silent` (no progress bar), and `| head -n` to only print 3 lines)

# %% [markdown]
# the endpoint `https://api.github.com/users/lizre/learn-py` _serves_ the github API

# %% [markdown]
# # You can send requests and get responses in bash `curl` or in python `requests`

# %%
# !curl https://api.github.com/users/lizre/learn-py
# Out:
# {
#   "message": "Not Found",
#   "documentation_url": "https://docs.github.com/rest"
# }

# %%
import requests

response = requests.get(url = "https://api.github.com/users/lizre")

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# # `GET` is an HTTP _[method](https://docs.github.com/en/rest/using-the-rest-api/getting-started-with-the-rest-api?apiVersion=2022-11-28#http-method)_
#
# to request/read data

# %%
# !curl -s -X GET https://api.github.com/users/lizre  | head -n 3
# Out:
# {
#   "login": "lizre",
#   "id": 38010821,

# %% [markdown]
# If you leave `-X GET` out, it's implied/idenatical:

# %%
# !curl -s https://api.github.com/users/lizre  | head -n 3
# Out:
# {
#   "login": "lizre",
#   "id": 38010821,

# %% [markdown]
# ## other methods include `post`
#
# to send data
#
# _get_ methods do send data--the endpoint--but that's the only data they send.
#
# For `post`, there's a whole `data` argument:

# %%
response = requests.post(
                        "https://httpbin.org/post" # A simple HTTP Request & Response Service.
                        , data = {'name': 'me', 'email': 'me@example.com'}
                        )

response.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'email': 'me@example.com', 'name': 'me'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '30',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.31.0',
#   'X-Amzn-Trace-Id': 'Root=1-657dd90d-682bd05657d224de4b873699'},
#  'json': None,
#  'origin': '174.194.197.20',
#  'url': 'https://httpbin.org/post'}

# %% [markdown]
# # (HTTP) `header`s (`-H`) are metadata about the request or response

# %% [markdown]
# `Accept` is a common _request header_.
#
# It says content types the client can handle. In APIs, often used to say "i expect to get/accept responses in the format of this version"

# %%
# !curl -s -X GET -H "Accept: application/vnd.github.v3+json" https://api.github.com/users/lizre  | head -n 3
# Out:
# {
#   "login": "lizre",
#   "id": 38010821,

# %% [markdown]
# ### _response headers_ often include content type, length, encoding.

# %%
response.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Sat, 16 Dec 2023 17:14:16 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'X-GitHub-Media-Type': 'github.v3; format=json', 'x-github-api-version-selected': '2022-11-28', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '59', 'X-RateLimit-Reset': '1702750456', 'X-RateLimit-Used': '1', 'X-RateLimit-Resource': 'core', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Vary': 'Accept-Encoding, Accept, X-Requested-With', 'Content-Encoding': 'gzip', 'X-GitHub-Request-Id': '0FF7:95A8:16666AA:1753C9E:657DDAE8'}

# %% [markdown]
# # _Authorization Header_ grants you access to protected resources
#
# **_authentication_**: establish identity. Do this with _Bearer Tokens_
#
# **_authorization_**: grant access regardless of identity. do this with _api keys_.
#
# The github API uses _Personal Access Tokens_ to _authenticate_ that you're a certain person.
#
# [Make a PAT](https://docs.github.com/en/authentication/keeping-your-account-and-data-secure/managing-your-personal-access-tokens#creating-a-fine-grained-personal-access-token).
#
# Then use it as the `Authorization` _header_.

# %%
! curl \
  -H "Accept: application/vnd.github+json" \
  -H "Authorization: Bearer {YOURPATHERE}" \
  -H "X-GitHub-Api-Version: 2022-11-28" \
  https://api.github.com/users/lizre/repos
# Out:
# [
#   {
#     "id": 145179795,
#     "node_id": "MDEwOlJlcG9zaXRvcnkxNDUxNzk3OTU=",
#     "name": "detecting-bots",
#     "full_name": "lizre/detecting-bots",
#     "private": false,
#     "owner": {
#       "login": "lizre",
#       "id": 38010821,
#       "node_id": "MDQ6VXNlcjM4MDEwODIx",
#       "avatar_url": "https://avatars.githubusercontent.com/u/38010821?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/lizre",
#       "html_url": "https://github.com/lizre",
#       "followers_url": "https://api.github.com/users/lizre/followers",
#       "following_url": "https://api.github.com/users/lizre/following{/other_user}",
#       "gists_url": "https://api.github.com/users/lizre/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/lizre/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/lizre/subscriptions",
#       "organizations_url": "https://api.github.com/users/lizre/orgs",
#       "repos_url": "https://api.github.com/users/lizre/repos",
#       "events_url": "https://api.github.com/users/lizre/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/lizre/received_events",
#       "type": "User",
#       "site_admin": true
#     },
#     "html_url": "https://github.com/lizre/detecting-bots",
#     "description": "This is a function designed for Qualtrics surveys to detect responses that may be from bots and survey-farmers. ",
#     "fork": true,
#     "url": "https://api.github.com/repos/lizre/detecting-bots",
#     "forks_url": "https://api.github.com/repos/lizre/detecting-bots/forks",
#     "keys_url": "https://api.github.com/repos/lizre/detecting-bots/keys{/key_id}",
#     "collaborators_url": "https://api.github.com/repos/lizre/detecting-bots/collaborators{/collaborator}",
#     "teams_url": "https://api.github.com/repos/lizre/detecting-bots/teams",
#     "hooks_url": "https://api.github.com/repos/lizre/detecting-bots/hooks",
#     "issue_events_url": "https://api.github.com/repos/lizre/detecting-bots/issues/events{/number}",
#     "events_url": "https://api.github.com/repos/lizre/detecting-bots/events",
#     "assignees_url": "https://api.github.com/repos/lizre/detecting-bots/assignees{/user}",
#     "branches_url": "https://api.github.com/repos/lizre/detecting-bots/branches{/branch}",
#     "tags_url": "https://api.github.com/repos/lizre/detecting-bots/tags",
#     "blobs_url": "https://api.github.com/repos/lizre/detecting-bots/git/blobs{/sha}",
#     "git_tags_url": "https://api.github.com/repos/lizre/detecting-bots/git/tags{/sha}",
#     "git_refs_url": "https://api.github.com/repos/lizre/detecting-bots/git/refs{/sha}",
#     "trees_url": "https://api.github.com/repos/lizre/detecting-bots/git/trees{/sha}",
#     "statuses_url": "https://api.github.com/repos/lizre/detecting-bots/statuses/{sha}",
#     "languages_url": "https://api.github.com/repos/lizre/detecting-bots/languages",
#     "stargazers_url": "https://api.github.com/repos/lizre/detecting-bots/stargazers",
#     "contributors_url": "https://api.github.com/repos/lizre/detecting-bots/contributors",
#     "subscribers_url": "https://api.github.com/repos/lizre/detecting-bots/subscribers",
#     "subscription_url": "https://api.github.com/repos/lizre/detecting-bots/subscription",
#     "commits_url": "https://api.github.com/repos/lizre/detecting-bots/commits{/sha}",
#     "git_commits_url": "https://api.github.com/repos/lizre/detecting-bots/git/commits{/sha}",
#     "comments_url": "https://api.github.com/repos/lizre/detecting-bots/comments{/number}",
#     "issue_comment_url": "https://api.github.com/repos/lizre/detecting-bots/issues/comments{/number}",
#     "contents_url": "https://api.github.com/repos/lizre/detecting-bots/contents/{+path}",
#     "compare_url": "https://api.github.com/repos/lizre/detecting-bots/compare/{base}...{head}",
#     "merges_url": "https://api.github.com/repos/lizre/detecting-bots/merges",
#     "archive_url": "https://api.github.com/repos/lizre/detecting-bots/{archive_format}{/ref}",
#     "downloads_url": "https://api.github.com/repos/lizre/detecting-bots/downloads",
#     "issues_url": "https://api.github.com/repos/lizre/detecting-bots/issues{/number}",
#     "pulls_url": "https://api.github.com/repos/lizre/detecting-bots/pulls{/number}",
#     "milestones_url": "https://api.github.com/repos/lizre/detecting-bots/milestones{/number}",
#     "notifications_url": "https://api.github.com/repos/lizre/detecting-bots/notifications{?since,all,participating}",
#     "labels_url": "https://api.github.com/repos/lizre/detecting-bots/labels{/name}",
#     "releases_url": "https://api.github.com/repos/lizre/detecting-bots/releases{/id}",
#     "deployments_url": "https://api.github.com/repos/lizre/detecting-bots/deployments",
#     "created_at": "2018-08-18T01:17:45Z",
#     "updated_at": "2018-08-18T01:23:32Z",
#     "pushed_at": "2018-08-18T01:23:30Z",
#     "git_url": "git://github.com/lizre/detecting-bots.git",
#     "ssh_url": "git@github.com:lizre/detecting-bots.git",
#     "clone_url": "https://github.com/lizre/detecting-bots.git",
#     "svn_url": "https://github.com/lizre/detecting-bots",
#     "homepage": null,
#     "size": 39,
#     "stargazers_count": 0,
#     "watchers_count": 0,
#     "language": "R",
#     "has_issues": false,
#     "has_projects": true,
#     "has_downloads": true,
#     "has_wiki": true,
#     "has_pages": false,
#     "has_discussions": false,
#     "forks_count": 0,
#     "mirror_url": null,
#     "archived": false,
#     "disabled": false,
#     "open_issues_count": 0,
#     "license": null,
#     "allow_forking": true,
#     "is_template": false,
#     "web_commit_signoff_required": false,
#     "topics": [
#
#     ],
#     "visibility": "public",
#     "forks": 0,
#     "open_issues": 0,
#     "watchers": 0,
#     "default_branch": "master",
#     "permissions": {
#       "admin": true,
#       "maintain": true,
#       "push": true,
#       "triage": true,
#       "pull": true
#     }
#   },
#   {
#     "id": 141456023,
#     "node_id": "MDEwOlJlcG9zaXRvcnkxNDE0NTYwMjM=",
#     "name": "empathy-humanitarianism-prosociality",
#     "full_name": "lizre/empathy-humanitarianism-prosociality",
#     "private": false,
#     "owner": {
#       "login": "lizre",
#       "id": 38010821,
#       "node_id": "MDQ6VXNlcjM4MDEwODIx",
#       "avatar_url": "https://avatars.githubusercontent.com/u/38010821?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/lizre",
#       "html_url": "https://github.com/lizre",
#       "followers_url": "https://api.github.com/users/lizre/followers",
#       "following_url": "https://api.github.com/users/lizre/following{/other_user}",
#       "gists_url": "https://api.github.com/users/lizre/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/lizre/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/lizre/subscriptions",
#       "organizations_url": "https://api.github.com/users/lizre/orgs",
#       "repos_url": "https://api.github.com/users/lizre/repos",
#       "events_url": "https://api.github.com/users/lizre/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/lizre/received_events",
#       "type": "User",
#       "site_admin": true
#     },
#     "html_url": "https://github.com/lizre/empathy-humanitarianism-prosociality",
#     "description": "Data, materials and SPSS syntax for empirical paper \"Empathy and humanitarianism predict preferential moral responsiveness to in-groups and out-groups\", published in The Journal of Social Psychology, by Liz Redford and Kate A. Ratliff.",
#     "fork": false,
#     "url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality",
#     "forks_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/forks",
#     "keys_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/keys{/key_id}",
#     "collaborators_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/collaborators{/collaborator}",
#     "teams_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/teams",
#     "hooks_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/hooks",
#     "issue_events_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/issues/events{/number}",
#     "events_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/events",
#     "assignees_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/assignees{/user}",
#     "branches_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/branches{/branch}",
#     "tags_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/tags",
#     "blobs_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/git/blobs{/sha}",
#     "git_tags_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/git/tags{/sha}",
#     "git_refs_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/git/refs{/sha}",
#     "trees_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/git/trees{/sha}",
#     "statuses_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/statuses/{sha}",
#     "languages_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/languages",
#     "stargazers_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/stargazers",
#     "contributors_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/contributors",
#     "subscribers_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/subscribers",
#     "subscription_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/subscription",
#     "commits_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/commits{/sha}",
#     "git_commits_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/git/commits{/sha}",
#     "comments_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/comments{/number}",
#     "issue_comment_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/issues/comments{/number}",
#     "contents_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/contents/{+path}",
#     "compare_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/compare/{base}...{head}",
#     "merges_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/merges",
#     "archive_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/{archive_format}{/ref}",
#     "downloads_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/downloads",
#     "issues_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/issues{/number}",
#     "pulls_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/pulls{/number}",
#     "milestones_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/milestones{/number}",
#     "notifications_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/notifications{?since,all,participating}",
#     "labels_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/labels{/name}",
#     "releases_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/releases{/id}",
#     "deployments_url": "https://api.github.com/repos/lizre/empathy-humanitarianism-prosociality/deployments",
#     "created_at": "2018-07-18T15:43:07Z",
#     "updated_at": "2018-07-20T14:56:04Z",
#     "pushed_at": "2018-07-20T14:56:02Z",
#     "git_url": "git://github.com/lizre/empathy-humanitarianism-prosociality.git",
#     "ssh_url": "git@github.com:lizre/empathy-humanitarianism-prosociality.git",
#     "clone_url": "https://github.com/lizre/empathy-humanitarianism-prosociality.git",
#     "svn_url": "https://github.com/lizre/empathy-humanitarianism-prosociality",
#     "homepage": "",
#     "size": 2216,
#     "stargazers_count": 0,
#     "watchers_count": 0,
#     "language": "Scheme",
#     "has_issues": true,
#     "has_projects": true,
#     "has_downloads": true,
#     "has_wiki": true,
#     "has_pages": false,
#     "has_discussions": false,
#     "forks_count": 0,
#     "mirror_url": null,
#     "archived": false,
#     "disabled": false,
#     "open_issues_count": 0,
#     "license": null,
#     "allow_forking": true,
#     "is_template": false,
#     "web_commit_signoff_required": false,
#     "topics": [
#
#     ],
#     "visibility": "public",
#     "forks": 0,
#     "open_issues": 0,
#     "watchers": 0,
#     "default_branch": "master",
#     "permissions": {
#       "admin": true,
#       "maintain": true,
#       "push": true,
#       "triage": true,
#       "pull": true
#     }
#   },
#   {
#     "id": 139336332,
#     "node_id": "MDEwOlJlcG9zaXRvcnkxMzkzMzYzMzI=",
#     "name": "explore-iat",
#     "full_name": "lizre/explore-iat",
#     "private": false,
#     "owner": {
#       "login": "lizre",
#       "id": 38010821,
#       "node_id": "MDQ6VXNlcjM4MDEwODIx",
#       "avatar_url": "https://avatars.githubusercontent.com/u/38010821?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/lizre",
#       "html_url": "https://github.com/lizre",
#       "followers_url": "https://api.github.com/users/lizre/followers",
#       "following_url": "https://api.github.com/users/lizre/following{/other_user}",
#       "gists_url": "https://api.github.com/users/lizre/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/lizre/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/lizre/subscriptions",
#       "organizations_url": "https://api.github.com/users/lizre/orgs",
#       "repos_url": "https://api.github.com/users/lizre/repos",
#       "events_url": "https://api.github.com/users/lizre/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/lizre/received_events",
#       "type": "User",
#       "site_admin": true
#     },
#     "html_url": "https://github.com/lizre/explore-iat",
#     "description": "A Shinydashboard that shows descriptive stats and correlations for several Implicit Association Tests.",
#     "fork": false,
#     "url": "https://api.github.com/repos/lizre/explore-iat",
#     "forks_url": "https://api.github.com/repos/lizre/explore-iat/forks",
#     "keys_url": "https://api.github.com/repos/lizre/explore-iat/keys{/key_id}",
#     "collaborators_url": "https://api.github.com/repos/lizre/explore-iat/collaborators{/collaborator}",
#     "teams_url": "https://api.github.com/repos/lizre/explore-iat/teams",
#     "hooks_url": "https://api.github.com/repos/lizre/explore-iat/hooks",
#     "issue_events_url": "https://api.github.com/repos/lizre/explore-iat/issues/events{/number}",
#     "events_url": "https://api.github.com/repos/lizre/explore-iat/events",
#     "assignees_url": "https://api.github.com/repos/lizre/explore-iat/assignees{/user}",
#     "branches_url": "https://api.github.com/repos/lizre/explore-iat/branches{/branch}",
#     "tags_url": "https://api.github.com/repos/lizre/explore-iat/tags",
#     "blobs_url": "https://api.github.com/repos/lizre/explore-iat/git/blobs{/sha}",
#     "git_tags_url": "https://api.github.com/repos/lizre/explore-iat/git/tags{/sha}",
#     "git_refs_url": "https://api.github.com/repos/lizre/explore-iat/git/refs{/sha}",
#     "trees_url": "https://api.github.com/repos/lizre/explore-iat/git/trees{/sha}",
#     "statuses_url": "https://api.github.com/repos/lizre/explore-iat/statuses/{sha}",
#     "languages_url": "https://api.github.com/repos/lizre/explore-iat/languages",
#     "stargazers_url": "https://api.github.com/repos/lizre/explore-iat/stargazers",
#     "contributors_url": "https://api.github.com/repos/lizre/explore-iat/contributors",
#     "subscribers_url": "https://api.github.com/repos/lizre/explore-iat/subscribers",
#     "subscription_url": "https://api.github.com/repos/lizre/explore-iat/subscription",
#     "commits_url": "https://api.github.com/repos/lizre/explore-iat/commits{/sha}",
#     "git_commits_url": "https://api.github.com/repos/lizre/explore-iat/git/commits{/sha}",
#     "comments_url": "https://api.github.com/repos/lizre/explore-iat/comments{/number}",
#     "issue_comment_url": "https://api.github.com/repos/lizre/explore-iat/issues/comments{/number}",
#     "contents_url": "https://api.github.com/repos/lizre/explore-iat/contents/{+path}",
#     "compare_url": "https://api.github.com/repos/lizre/explore-iat/compare/{base}...{head}",
#     "merges_url": "https://api.github.com/repos/lizre/explore-iat/merges",
#     "archive_url": "https://api.github.com/repos/lizre/explore-iat/{archive_format}{/ref}",
#     "downloads_url": "https://api.github.com/repos/lizre/explore-iat/downloads",
#     "issues_url": "https://api.github.com/repos/lizre/explore-iat/issues{/number}",
#     "pulls_url": "https://api.github.com/repos/lizre/explore-iat/pulls{/number}",
#     "milestones_url": "https://api.github.com/repos/lizre/explore-iat/milestones{/number}",
#     "notifications_url": "https://api.github.com/repos/lizre/explore-iat/notifications{?since,all,participating}",
#     "labels_url": "https://api.github.com/repos/lizre/explore-iat/labels{/name}",
#     "releases_url": "https://api.github.com/repos/lizre/explore-iat/releases{/id}",
#     "deployments_url": "https://api.github.com/repos/lizre/explore-iat/deployments",
#     "created_at": "2018-07-01T14:34:41Z",
#     "updated_at": "2019-12-11T16:15:25Z",
#     "pushed_at": "2018-10-05T15:10:00Z",
#     "git_url": "git://github.com/lizre/explore-iat.git",
#     "ssh_url": "git@github.com:lizre/explore-iat.git",
#     "clone_url": "https://github.com/lizre/explore-iat.git",
#     "svn_url": "https://github.com/lizre/explore-iat",
#     "homepage": "",
#     "size": 1372,
#     "stargazers_count": 1,
#     "watchers_count": 1,
#     "language": "R",
#     "has_issues": true,
#     "has_projects": true,
#     "has_downloads": true,
#     "has_wiki": true,
#     "has_pages": false,
#     "has_discussions": false,
#     "forks_count": 0,
#     "mirror_url": null,
#     "archived": false,
#     "disabled": false,
#     "open_issues_count": 0,
#     "license": null,
#     "allow_forking": true,
#     "is_template": false,
#     "web_commit_signoff_required": false,
#     "topics": [
#
#     ],
#     "visibility": "public",
#     "forks": 0,
#     "open_issues": 0,
#     "watchers": 1,
#     "default_branch": "master",
#     "permissions": {
#       "admin": true,
#       "maintain": true,
#       "push": true,
#       "triage": true,
#       "pull": true
#     }
#   },
#   {
#     "id": 145910579,
#     "node_id": "MDEwOlJlcG9zaXRvcnkxNDU5MTA1Nzk=",
#     "name": "gendersciatts-py",
#     "full_name": "lizre/gendersciatts-py",
#     "private": false,
#     "owner": {
#       "login": "lizre",
#       "id": 38010821,
#       "node_id": "MDQ6VXNlcjM4MDEwODIx",
#       "avatar_url": "https://avatars.githubusercontent.com/u/38010821?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/lizre",
#       "html_url": "https://github.com/lizre",
#       "followers_url": "https://api.github.com/users/lizre/followers",
#       "following_url": "https://api.github.com/users/lizre/following{/other_user}",
#       "gists_url": "https://api.github.com/users/lizre/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/lizre/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/lizre/subscriptions",
#       "organizations_url": "https://api.github.com/users/lizre/orgs",
#       "repos_url": "https://api.github.com/users/lizre/repos",
#       "events_url": "https://api.github.com/users/lizre/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/lizre/received_events",
#       "type": "User",
#       "site_admin": true
#     },
#     "html_url": "https://github.com/lizre/gendersciatts-py",
#     "description": "These notebooks use pandas, matplotlib, seaborn, scipy, statsmodels, and scikit-learn to explore, conduct inferential descriptives, create visualizations, and build predictive models using the publicly-available Project Implicit data from the Gender-Science Implicit Association Test.",
#     "fork": false,
#     "url": "https://api.github.com/repos/lizre/gendersciatts-py",
#     "forks_url": "https://api.github.com/repos/lizre/gendersciatts-py/forks",
#     "keys_url": "https://api.github.com/repos/lizre/gendersciatts-py/keys{/key_id}",
#     "collaborators_url": "https://api.github.com/repos/lizre/gendersciatts-py/collaborators{/collaborator}",
#     "teams_url": "https://api.github.com/repos/lizre/gendersciatts-py/teams",
#     "hooks_url": "https://api.github.com/repos/lizre/gendersciatts-py/hooks",
#     "issue_events_url": "https://api.github.com/repos/lizre/gendersciatts-py/issues/events{/number}",
#     "events_url": "https://api.github.com/repos/lizre/gendersciatts-py/events",
#     "assignees_url": "https://api.github.com/repos/lizre/gendersciatts-py/assignees{/user}",
#     "branches_url": "https://api.github.com/repos/lizre/gendersciatts-py/branches{/branch}",
#     "tags_url": "https://api.github.com/repos/lizre/gendersciatts-py/tags",
#     "blobs_url": "https://api.github.com/repos/lizre/gendersciatts-py/git/blobs{/sha}",
#     "git_tags_url": "https://api.github.com/repos/lizre/gendersciatts-py/git/tags{/sha}",
#     "git_refs_url": "https://api.github.com/repos/lizre/gendersciatts-py/git/refs{/sha}",
#     "trees_url": "https://api.github.com/repos/lizre/gendersciatts-py/git/trees{/sha}",
#     "statuses_url": "https://api.github.com/repos/lizre/gendersciatts-py/statuses/{sha}",
#     "languages_url": "https://api.github.com/repos/lizre/gendersciatts-py/languages",
#     "stargazers_url": "https://api.github.com/repos/lizre/gendersciatts-py/stargazers",
#     "contributors_url": "https://api.github.com/repos/lizre/gendersciatts-py/contributors",
#     "subscribers_url": "https://api.github.com/repos/lizre/gendersciatts-py/subscribers",
#     "subscription_url": "https://api.github.com/repos/lizre/gendersciatts-py/subscription",
#     "commits_url": "https://api.github.com/repos/lizre/gendersciatts-py/commits{/sha}",
#     "git_commits_url": "https://api.github.com/repos/lizre/gendersciatts-py/git/commits{/sha}",
#     "comments_url": "https://api.github.com/repos/lizre/gendersciatts-py/comments{/number}",
#     "issue_comment_url": "https://api.github.com/repos/lizre/gendersciatts-py/issues/comments{/number}",
#     "contents_url": "https://api.github.com/repos/lizre/gendersciatts-py/contents/{+path}",
#     "compare_url": "https://api.github.com/repos/lizre/gendersciatts-py/compare/{base}...{head}",
#     "merges_url": "https://api.github.com/repos/lizre/gendersciatts-py/merges",
#     "archive_url": "https://api.github.com/repos/lizre/gendersciatts-py/{archive_format}{/ref}",
#     "downloads_url": "https://api.github.com/repos/lizre/gendersciatts-py/downloads",
#     "issues_url": "https://api.github.com/repos/lizre/gendersciatts-py/issues{/number}",
#     "pulls_url": "https://api.github.com/repos/lizre/gendersciatts-py/pulls{/number}",
#     "milestones_url": "https://api.github.com/repos/lizre/gendersciatts-py/milestones{/number}",
#     "notifications_url": "https://api.github.com/repos/lizre/gendersciatts-py/notifications{?since,all,participating}",
#     "labels_url": "https://api.github.com/repos/lizre/gendersciatts-py/labels{/name}",
#     "releases_url": "https://api.github.com/repos/lizre/gendersciatts-py/releases{/id}",
#     "deployments_url": "https://api.github.com/repos/lizre/gendersciatts-py/deployments",
#     "created_at": "2018-08-23T21:48:14Z",
#     "updated_at": "2020-11-07T23:34:13Z",
#     "pushed_at": "2020-11-07T23:34:11Z",
#     "git_url": "git://github.com/lizre/gendersciatts-py.git",
#     "ssh_url": "git@github.com:lizre/gendersciatts-py.git",
#     "clone_url": "https://github.com/lizre/gendersciatts-py.git",
#     "svn_url": "https://github.com/lizre/gendersciatts-py",
#     "homepage": "",
#     "size": 493,
#     "stargazers_count": 0,
#     "watchers_count": 0,
#     "language": "Jupyter Notebook",
#     "has_issues": true,
#     "has_projects": true,
#     "has_downloads": true,
#     "has_wiki": true,
#     "has_pages": false,
#     "has_discussions": false,
#     "forks_count": 0,
#     "mirror_url": null,
#     "archived": false,
#     "disabled": false,
#     "open_issues_count": 0,
#     "license": null,
#     "allow_forking": true,
#     "is_template": false,
#     "web_commit_signoff_required": false,
#     "topics": [
#
#     ],
#     "visibility": "public",
#     "forks": 0,
#     "open_issues": 0,
#     "watchers": 0,
#     "default_branch": "master",
#     "permissions": {
#       "admin": true,
#       "maintain": true,
#       "push": true,
#       "triage": true,
#       "pull": true
#     }
#   },
#   {
#     "id": 483656709,
#     "node_id": "R_kgDOHNQEBQ",
#     "name": "github-actions-continuous-delivery-azure",
#     "full_name": "lizre/github-actions-continuous-delivery-azure",
#     "private": false,
#     "owner": {
#       "login": "lizre",
#       "id": 38010821,
#       "node_id": "MDQ6VXNlcjM4MDEwODIx",
#       "avatar_url": "https://avatars.githubusercontent.com/u/38010821?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/lizre",
#       "html_url": "https://github.com/lizre",
#       "followers_url": "https://api.github.com/users/lizre/followers",
#       "following_url": "https://api.github.com/users/lizre/following{/other_user}",
#       "gists_url": "https://api.github.com/users/lizre/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/lizre/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/lizre/subscriptions",
#       "organizations_url": "https://api.github.com/users/lizre/orgs",
#       "repos_url": "https://api.github.com/users/lizre/repos",
#       "events_url": "https://api.github.com/users/lizre/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/lizre/received_events",
#       "type": "User",
#       "site_admin": true
#     },
#     "html_url": "https://github.com/lizre/github-actions-continuous-delivery-azure",
#     "description": null,
#     "fork": false,
#     "url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure",
#     "forks_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/forks",
#     "keys_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/keys{/key_id}",
#     "collaborators_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/collaborators{/collaborator}",
#     "teams_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/teams",
#     "hooks_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/hooks",
#     "issue_events_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/issues/events{/number}",
#     "events_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/events",
#     "assignees_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/assignees{/user}",
#     "branches_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/branches{/branch}",
#     "tags_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/tags",
#     "blobs_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/git/blobs{/sha}",
#     "git_tags_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/git/tags{/sha}",
#     "git_refs_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/git/refs{/sha}",
#     "trees_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/git/trees{/sha}",
#     "statuses_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/statuses/{sha}",
#     "languages_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/languages",
#     "stargazers_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/stargazers",
#     "contributors_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/contributors",
#     "subscribers_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/subscribers",
#     "subscription_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/subscription",
#     "commits_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/commits{/sha}",
#     "git_commits_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/git/commits{/sha}",
#     "comments_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/comments{/number}",
#     "issue_comment_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/issues/comments{/number}",
#     "contents_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/contents/{+path}",
#     "compare_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/compare/{base}...{head}",
#     "merges_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/merges",
#     "archive_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/{archive_format}{/ref}",
#     "downloads_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/downloads",
#     "issues_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/issues{/number}",
#     "pulls_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/pulls{/number}",
#     "milestones_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/milestones{/number}",
#     "notifications_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/notifications{?since,all,participating}",
#     "labels_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/labels{/name}",
#     "releases_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/releases{/id}",
#     "deployments_url": "https://api.github.com/repos/lizre/github-actions-continuous-delivery-azure/deployments",
#     "created_at": "2022-04-20T13:01:44Z",
#     "updated_at": "2022-04-20T13:01:54Z",
#     "pushed_at": "2022-04-20T13:01:52Z",
#     "git_url": "git://github.com/lizre/github-actions-continuous-delivery-azure.git",
#     "ssh_url": "git@github.com:lizre/github-actions-continuous-delivery-azure.git",
#     "clone_url": "https://github.com/lizre/github-actions-continuous-delivery-azure.git",
#     "svn_url": "https://github.com/lizre/github-actions-continuous-delivery-azure",
#     "homepage": "https://lab.github.com/githubtraining/github-actions:-continuous-delivery-with-azure",
#     "size": 145,
#     "stargazers_count": 0,
#     "watchers_count": 0,
#     "language": "JavaScript",
#     "has_issues": true,
#     "has_projects": true,
#     "has_downloads": true,
#     "has_wiki": true,
#     "has_pages": false,
#     "has_discussions": false,
#     "forks_count": 0,
#     "mirror_url": null,
#     "archived": false,
#     "disabled": false,
#     "open_issues_count": 1,
#     "license": {
#       "key": "mit",
#       "name": "MIT License",
#       "spdx_id": "MIT",
#       "url": "https://api.github.com/licenses/mit",
#       "node_id": "MDc6TGljZW5zZTEz"
#     },
#     "allow_forking": true,
#     "is_template": false,
#     "web_commit_signoff_required": false,
#     "topics": [
#
#     ],
#     "visibility": "public",
#     "forks": 0,
#     "open_issues": 1,
#     "watchers": 0,
#     "default_branch": "main",
#     "permissions": {
#       "admin": true,
#       "maintain": true,
#       "push": true,
#       "triage": true,
#       "pull": true
#     }
#   },
#   {
#     "id": 405159778,
#     "node_id": "MDEwOlJlcG9zaXRvcnk0MDUxNTk3Nzg=",
#     "name": "github-actions-for-ci",
#     "full_name": "lizre/github-actions-for-ci",
#     "private": false,
#     "owner": {
#       "login": "lizre",
#       "id": 38010821,
#       "node_id": "MDQ6VXNlcjM4MDEwODIx",
#       "avatar_url": "https://avatars.githubusercontent.com/u/38010821?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/lizre",
#       "html_url": "https://github.com/lizre",
#       "followers_url": "https://api.github.com/users/lizre/followers",
#       "following_url": "https://api.github.com/users/lizre/following{/other_user}",
#       "gists_url": "https://api.github.com/users/lizre/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/lizre/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/lizre/subscriptions",
#       "organizations_url": "https://api.github.com/users/lizre/orgs",
#       "repos_url": "https://api.github.com/users/lizre/repos",
#       "events_url": "https://api.github.com/users/lizre/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/lizre/received_events",
#       "type": "User",
#       "site_admin": true
#     },
#     "html_url": "https://github.com/lizre/github-actions-for-ci",
#     "description": null,
#     "fork": false,
#     "url": "https://api.github.com/repos/lizre/github-actions-for-ci",
#     "forks_url": "https://api.github.com/repos/lizre/github-actions-for-ci/forks",
#     "keys_url": "https://api.github.com/repos/lizre/github-actions-for-ci/keys{/key_id}",
#     "collaborators_url": "https://api.github.com/repos/lizre/github-actions-for-ci/collaborators{/collaborator}",
#     "teams_url": "https://api.github.com/repos/lizre/github-actions-for-ci/teams",
#     "hooks_url": "https://api.github.com/repos/lizre/github-actions-for-ci/hooks",
#     "issue_events_url": "https://api.github.com/repos/lizre/github-actions-for-ci/issues/events{/number}",
#     "events_url": "https://api.github.com/repos/lizre/github-actions-for-ci/events",
#     "assignees_url": "https://api.github.com/repos/lizre/github-actions-for-ci/assignees{/user}",
#     "branches_url": "https://api.github.com/repos/lizre/github-actions-for-ci/branches{/branch}",
#     "tags_url": "https://api.github.com/repos/lizre/github-actions-for-ci/tags",
#     "blobs_url": "https://api.github.com/repos/lizre/github-actions-for-ci/git/blobs{/sha}",
#     "git_tags_url": "https://api.github.com/repos/lizre/github-actions-for-ci/git/tags{/sha}",
#     "git_refs_url": "https://api.github.com/repos/lizre/github-actions-for-ci/git/refs{/sha}",
#     "trees_url": "https://api.github.com/repos/lizre/github-actions-for-ci/git/trees{/sha}",
#     "statuses_url": "https://api.github.com/repos/lizre/github-actions-for-ci/statuses/{sha}",
#     "languages_url": "https://api.github.com/repos/lizre/github-actions-for-ci/languages",
#     "stargazers_url": "https://api.github.com/repos/lizre/github-actions-for-ci/stargazers",
#     "contributors_url": "https://api.github.com/repos/lizre/github-actions-for-ci/contributors",
#     "subscribers_url": "https://api.github.com/repos/lizre/github-actions-for-ci/subscribers",
#     "subscription_url": "https://api.github.com/repos/lizre/github-actions-for-ci/subscription",
#     "commits_url": "https://api.github.com/repos/lizre/github-actions-for-ci/commits{/sha}",
#     "git_commits_url": "https://api.github.com/repos/lizre/github-actions-for-ci/git/commits{/sha}",
#     "comments_url": "https://api.github.com/repos/lizre/github-actions-for-ci/comments{/number}",
#     "issue_comment_url": "https://api.github.com/repos/lizre/github-actions-for-ci/issues/comments{/number}",
#     "contents_url": "https://api.github.com/repos/lizre/github-actions-for-ci/contents/{+path}",
#     "compare_url": "https://api.github.com/repos/lizre/github-actions-for-ci/compare/{base}...{head}",
#     "merges_url": "https://api.github.com/repos/lizre/github-actions-for-ci/merges",
#     "archive_url": "https://api.github.com/repos/lizre/github-actions-for-ci/{archive_format}{/ref}",
#     "downloads_url": "https://api.github.com/repos/lizre/github-actions-for-ci/downloads",
#     "issues_url": "https://api.github.com/repos/lizre/github-actions-for-ci/issues{/number}",
#     "pulls_url": "https://api.github.com/repos/lizre/github-actions-for-ci/pulls{/number}",
#     "milestones_url": "https://api.github.com/repos/lizre/github-actions-for-ci/milestones{/number}",
#     "notifications_url": "https://api.github.com/repos/lizre/github-actions-for-ci/notifications{?since,all,participating}",
#     "labels_url": "https://api.github.com/repos/lizre/github-actions-for-ci/labels{/name}",
#     "releases_url": "https://api.github.com/repos/lizre/github-actions-for-ci/releases{/id}",
#     "deployments_url": "https://api.github.com/repos/lizre/github-actions-for-ci/deployments",
#     "created_at": "2021-09-10T17:21:22Z",
#     "updated_at": "2021-09-10T17:21:28Z",
#     "pushed_at": "2021-09-11T13:17:38Z",
#     "git_url": "git://github.com/lizre/github-actions-for-ci.git",
#     "ssh_url": "git@github.com:lizre/github-actions-for-ci.git",
#     "clone_url": "https://github.com/lizre/github-actions-for-ci.git",
#     "svn_url": "https://github.com/lizre/github-actions-for-ci",
#     "homepage": "https://lab.github.com/githubtraining/github-actions:-continuous-integration",
#     "size": 157,
#     "stargazers_count": 0,
#     "watchers_count": 0,
#     "language": "JavaScript",
#     "has_issues": true,
#     "has_projects": true,
#     "has_downloads": true,
#     "has_wiki": true,
#     "has_pages": false,
#     "has_discussions": false,
#     "forks_count": 0,
#     "mirror_url": null,
#     "archived": false,
#     "disabled": false,
#     "open_issues_count": 3,
#     "license": {
#       "key": "mit",
#       "name": "MIT License",
#       "spdx_id": "MIT",
#       "url": "https://api.github.com/licenses/mit",
#       "node_id": "MDc6TGljZW5zZTEz"
#     },
#     "allow_forking": true,
#     "is_template": false,
#     "web_commit_signoff_required": false,
#     "topics": [
#
#     ],
#     "visibility": "public",
#     "forks": 0,
#     "open_issues": 3,
#     "watchers": 0,
#     "default_branch": "main",
#     "permissions": {
#       "admin": true,
#       "maintain": true,
#       "push": true,
#       "triage": true,
#       "pull": true
#     }
#   },
#   {
#     "id": 483339192,
#     "node_id": "R_kgDOHM8ruA",
#     "name": "go-app",
#     "full_name": "lizre/go-app",
#     "private": false,
#     "owner": {
#       "login": "lizre",
#       "id": 38010821,
#       "node_id": "MDQ6VXNlcjM4MDEwODIx",
#       "avatar_url": "https://avatars.githubusercontent.com/u/38010821?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/lizre",
#       "html_url": "https://github.com/lizre",
#       "followers_url": "https://api.github.com/users/lizre/followers",
#       "following_url": "https://api.github.com/users/lizre/following{/other_user}",
#       "gists_url": "https://api.github.com/users/lizre/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/lizre/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/lizre/subscriptions",
#       "organizations_url": "https://api.github.com/users/lizre/orgs",
#       "repos_url": "https://api.github.com/users/lizre/repos",
#       "events_url": "https://api.github.com/users/lizre/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/lizre/received_events",
#       "type": "User",
#       "site_admin": true
#     },
#     "html_url": "https://github.com/lizre/go-app",
#     "description": null,
#     "fork": false,
#     "url": "https://api.github.com/repos/lizre/go-app",
#     "forks_url": "https://api.github.com/repos/lizre/go-app/forks",
#     "keys_url": "https://api.github.com/repos/lizre/go-app/keys{/key_id}",
#     "collaborators_url": "https://api.github.com/repos/lizre/go-app/collaborators{/collaborator}",
#     "teams_url": "https://api.github.com/repos/lizre/go-app/teams",
#     "hooks_url": "https://api.github.com/repos/lizre/go-app/hooks",
#     "issue_events_url": "https://api.github.com/repos/lizre/go-app/issues/events{/number}",
#     "events_url": "https://api.github.com/repos/lizre/go-app/events",
#     "assignees_url": "https://api.github.com/repos/lizre/go-app/assignees{/user}",
#     "branches_url": "https://api.github.com/repos/lizre/go-app/branches{/branch}",
#     "tags_url": "https://api.github.com/repos/lizre/go-app/tags",
#     "blobs_url": "https://api.github.com/repos/lizre/go-app/git/blobs{/sha}",
#     "git_tags_url": "https://api.github.com/repos/lizre/go-app/git/tags{/sha}",
#     "git_refs_url": "https://api.github.com/repos/lizre/go-app/git/refs{/sha}",
#     "trees_url": "https://api.github.com/repos/lizre/go-app/git/trees{/sha}",
#     "statuses_url": "https://api.github.com/repos/lizre/go-app/statuses/{sha}",
#     "languages_url": "https://api.github.com/repos/lizre/go-app/languages",
#     "stargazers_url": "https://api.github.com/repos/lizre/go-app/stargazers",
#     "contributors_url": "https://api.github.com/repos/lizre/go-app/contributors",
#     "subscribers_url": "https://api.github.com/repos/lizre/go-app/subscribers",
#     "subscription_url": "https://api.github.com/repos/lizre/go-app/subscription",
#     "commits_url": "https://api.github.com/repos/lizre/go-app/commits{/sha}",
#     "git_commits_url": "https://api.github.com/repos/lizre/go-app/git/commits{/sha}",
#     "comments_url": "https://api.github.com/repos/lizre/go-app/comments{/number}",
#     "issue_comment_url": "https://api.github.com/repos/lizre/go-app/issues/comments{/number}",
#     "contents_url": "https://api.github.com/repos/lizre/go-app/contents/{+path}",
#     "compare_url": "https://api.github.com/repos/lizre/go-app/compare/{base}...{head}",
#     "merges_url": "https://api.github.com/repos/lizre/go-app/merges",
#     "archive_url": "https://api.github.com/repos/lizre/go-app/{archive_format}{/ref}",
#     "downloads_url": "https://api.github.com/repos/lizre/go-app/downloads",
#     "issues_url": "https://api.github.com/repos/lizre/go-app/issues{/number}",
#     "pulls_url": "https://api.github.com/repos/lizre/go-app/pulls{/number}",
#     "milestones_url": "https://api.github.com/repos/lizre/go-app/milestones{/number}",
#     "notifications_url": "https://api.github.com/repos/lizre/go-app/notifications{?since,all,participating}",
#     "labels_url": "https://api.github.com/repos/lizre/go-app/labels{/name}",
#     "releases_url": "https://api.github.com/repos/lizre/go-app/releases{/id}",
#     "deployments_url": "https://api.github.com/repos/lizre/go-app/deployments",
#     "created_at": "2022-04-19T17:12:39Z",
#     "updated_at": "2022-04-19T17:13:31Z",
#     "pushed_at": "2022-04-20T13:08:25Z",
#     "git_url": "git://github.com/lizre/go-app.git",
#     "ssh_url": "git@github.com:lizre/go-app.git",
#     "clone_url": "https://github.com/lizre/go-app.git",
#     "svn_url": "https://github.com/lizre/go-app",
#     "homepage": null,
#     "size": 3,
#     "stargazers_count": 0,
#     "watchers_count": 0,
#     "language": "Makefile",
#     "has_issues": true,
#     "has_projects": true,
#     "has_downloads": true,
#     "has_wiki": true,
#     "has_pages": false,
#     "has_discussions": false,
#     "forks_count": 0,
#     "mirror_url": null,
#     "archived": false,
#     "disabled": false,
#     "open_issues_count": 0,
#     "license": null,
#     "allow_forking": true,
#     "is_template": false,
#     "web_commit_signoff_required": false,
#     "topics": [
#
#     ],
#     "visibility": "public",
#     "forks": 0,
#     "open_issues": 0,
#     "watchers": 0,
#     "default_branch": "master",
#     "permissions": {
#       "admin": true,
#       "maintain": true,
#       "push": true,
#       "triage": true,
#       "pull": true
#     }
#   },
#   {
#     "id": 483666655,
#     "node_id": "R_kgDOHNQq3w",
#     "name": "go-mathapp",
#     "full_name": "lizre/go-mathapp",
#     "private": false,
#     "owner": {
#       "login": "lizre",
#       "id": 38010821,
#       "node_id": "MDQ6VXNlcjM4MDEwODIx",
#       "avatar_url": "https://avatars.githubusercontent.com/u/38010821?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/lizre",
#       "html_url": "https://github.com/lizre",
#       "followers_url": "https://api.github.com/users/lizre/followers",
#       "following_url": "https://api.github.com/users/lizre/following{/other_user}",
#       "gists_url": "https://api.github.com/users/lizre/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/lizre/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/lizre/subscriptions",
#       "organizations_url": "https://api.github.com/users/lizre/orgs",
#       "repos_url": "https://api.github.com/users/lizre/repos",
#       "events_url": "https://api.github.com/users/lizre/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/lizre/received_events",
#       "type": "User",
#       "site_admin": true
#     },
#     "html_url": "https://github.com/lizre/go-mathapp",
#     "description": null,
#     "fork": false,
#     "url": "https://api.github.com/repos/lizre/go-mathapp",
#     "forks_url": "https://api.github.com/repos/lizre/go-mathapp/forks",
#     "keys_url": "https://api.github.com/repos/lizre/go-mathapp/keys{/key_id}",
#     "collaborators_url": "https://api.github.com/repos/lizre/go-mathapp/collaborators{/collaborator}",
#     "teams_url": "https://api.github.com/repos/lizre/go-mathapp/teams",
#     "hooks_url": "https://api.github.com/repos/lizre/go-mathapp/hooks",
#     "issue_events_url": "https://api.github.com/repos/lizre/go-mathapp/issues/events{/number}",
#     "events_url": "https://api.github.com/repos/lizre/go-mathapp/events",
#     "assignees_url": "https://api.github.com/repos/lizre/go-mathapp/assignees{/user}",
#     "branches_url": "https://api.github.com/repos/lizre/go-mathapp/branches{/branch}",
#     "tags_url": "https://api.github.com/repos/lizre/go-mathapp/tags",
#     "blobs_url": "https://api.github.com/repos/lizre/go-mathapp/git/blobs{/sha}",
#     "git_tags_url": "https://api.github.com/repos/lizre/go-mathapp/git/tags{/sha}",
#     "git_refs_url": "https://api.github.com/repos/lizre/go-mathapp/git/refs{/sha}",
#     "trees_url": "https://api.github.com/repos/lizre/go-mathapp/git/trees{/sha}",
#     "statuses_url": "https://api.github.com/repos/lizre/go-mathapp/statuses/{sha}",
#     "languages_url": "https://api.github.com/repos/lizre/go-mathapp/languages",
#     "stargazers_url": "https://api.github.com/repos/lizre/go-mathapp/stargazers",
#     "contributors_url": "https://api.github.com/repos/lizre/go-mathapp/contributors",
#     "subscribers_url": "https://api.github.com/repos/lizre/go-mathapp/subscribers",
#     "subscription_url": "https://api.github.com/repos/lizre/go-mathapp/subscription",
#     "commits_url": "https://api.github.com/repos/lizre/go-mathapp/commits{/sha}",
#     "git_commits_url": "https://api.github.com/repos/lizre/go-mathapp/git/commits{/sha}",
#     "comments_url": "https://api.github.com/repos/lizre/go-mathapp/comments{/number}",
#     "issue_comment_url": "https://api.github.com/repos/lizre/go-mathapp/issues/comments{/number}",
#     "contents_url": "https://api.github.com/repos/lizre/go-mathapp/contents/{+path}",
#     "compare_url": "https://api.github.com/repos/lizre/go-mathapp/compare/{base}...{head}",
#     "merges_url": "https://api.github.com/repos/lizre/go-mathapp/merges",
#     "archive_url": "https://api.github.com/repos/lizre/go-mathapp/{archive_format}{/ref}",
#     "downloads_url": "https://api.github.com/repos/lizre/go-mathapp/downloads",
#     "issues_url": "https://api.github.com/repos/lizre/go-mathapp/issues{/number}",
#     "pulls_url": "https://api.github.com/repos/lizre/go-mathapp/pulls{/number}",
#     "milestones_url": "https://api.github.com/repos/lizre/go-mathapp/milestones{/number}",
#     "notifications_url": "https://api.github.com/repos/lizre/go-mathapp/notifications{?since,all,participating}",
#     "labels_url": "https://api.github.com/repos/lizre/go-mathapp/labels{/name}",
#     "releases_url": "https://api.github.com/repos/lizre/go-mathapp/releases{/id}",
#     "deployments_url": "https://api.github.com/repos/lizre/go-mathapp/deployments",
#     "created_at": "2022-04-20T13:30:06Z",
#     "updated_at": "2022-04-20T13:30:06Z",
#     "pushed_at": "2022-04-20T13:31:31Z",
#     "git_url": "git://github.com/lizre/go-mathapp.git",
#     "ssh_url": "git@github.com:lizre/go-mathapp.git",
#     "clone_url": "https://github.com/lizre/go-mathapp.git",
#     "svn_url": "https://github.com/lizre/go-mathapp",
#     "homepage": null,
#     "size": 2,
#     "stargazers_count": 0,
#     "watchers_count": 0,
#     "language": null,
# ...
#     "subscribers_url": "https://api.github.com/repos/lizre/prophet-quickstart/subscribers",
#     "subscription_url": "https://api.github.com/repos/lizre/prophet-quickstart/subscription",
#     "commits_url": "https://api.github.com/repos/lizre/prophet-quickstart/commits{/sha}",
#     "git_commits_url": "https://api.github.com/repos/lizre/prophet-quickstart/git/commits{/sha}",
#     "comments_url": "https://api.github.com/repos/lizre/prophet-quickstart/comments{/number}",
#     "issue_comment_url": "https://api.github.com/repos/lizre/prophet-quickstart/issues/comments{/number}",
#     "contents_url": "https://api.github.com/repos/lizre/prophet-quickstart/contents/{+path}",
#     "compare_url": "https://api.github.com/repos/lizre/prophet-quickstart/compare/{base}...{head}",
#     "merges_url": "https://api.github.com/repos/lizre/prophet-quickstart/merges",
#     "archive_url": "https://api.github.com/repos/lizre/prophet-quickstart/{archive_format}{/ref}",
#     "downloads_url": "https://api.github.com/repos/lizre/prophet-quickstart/downloads",
#     "issues_url": "https://api.github.com/repos/lizre/prophet-quickstart/issues{/number}",
#     "pulls_url": "https://api.github.com/repos/lizre/prophet-quickstart/pulls{/number}",
#     "milestones_url": "https://api.github.com/repos/lizre/prophet-quickstart/milestones{/number}",
#     "notifications_url": "https://api.github.com/repos/lizre/prophet-quickstart/notifications{?since,all,participating}",
#     "labels_url": "https://api.github.com/repos/lizre/prophet-quickstart/labels{/name}",
#     "releases_url": "https://api.github.com/repos/lizre/prophet-quickstart/releases{/id}",
#     "deployments_url": "https://api.github.com/repos/lizre/prophet-quickstart/deployments",
#     "created_at": "2022-04-03T15:02:18Z",
#     "updated_at": "2022-04-04T13:59:18Z",
#     "pushed_at": "2022-04-05T17:11:04Z",
#     "git_url": "git://github.com/lizre/prophet-quickstart.git",
#     "ssh_url": "git@github.com:lizre/prophet-quickstart.git",
#     "clone_url": "https://github.com/lizre/prophet-quickstart.git",
#     "svn_url": "https://github.com/lizre/prophet-quickstart",
#     "homepage": null,
#     "size": 2363,
#     "stargazers_count": 0,
#     "watchers_count": 0,
#     "language": "Jupyter Notebook",
#     "has_issues": true,
#     "has_projects": true,
#     "has_downloads": true,
#     "has_wiki": true,
#     "has_pages": false,
#     "has_discussions": false,
#     "forks_count": 0,
#     "mirror_url": null,
#     "archived": false,
#     "disabled": false,
#     "open_issues_count": 0,
#     "license": null,
#     "allow_forking": true,
#     "is_template": false,
#     "web_commit_signoff_required": false,
#     "topics": [
#
#     ],
#     "visibility": "public",
#     "forks": 0,
#     "open_issues": 0,
#     "watchers": 0,
#     "default_branch": "master",
#     "permissions": {
#       "admin": true,
#       "maintain": true,
#       "push": true,
#       "triage": true,
#       "pull": true
#     }
#   },
#   {
#     "id": 141613216,
#     "node_id": "MDEwOlJlcG9zaXRvcnkxNDE2MTMyMTY=",
#     "name": "psychological-entitlement-justice",
#     "full_name": "lizre/psychological-entitlement-justice",
#     "private": false,
#     "owner": {
#       "login": "lizre",
#       "id": 38010821,
#       "node_id": "MDQ6VXNlcjM4MDEwODIx",
#       "avatar_url": "https://avatars.githubusercontent.com/u/38010821?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/lizre",
#       "html_url": "https://github.com/lizre",
#       "followers_url": "https://api.github.com/users/lizre/followers",
#       "following_url": "https://api.github.com/users/lizre/following{/other_user}",
#       "gists_url": "https://api.github.com/users/lizre/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/lizre/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/lizre/subscriptions",
#       "organizations_url": "https://api.github.com/users/lizre/orgs",
#       "repos_url": "https://api.github.com/users/lizre/repos",
#       "events_url": "https://api.github.com/users/lizre/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/lizre/received_events",
#       "type": "User",
#       "site_admin": true
#     },
#     "html_url": "https://github.com/lizre/psychological-entitlement-justice",
#     "description": " Data and SPSS syntax for empirical paper, \"Pride and punishment: Entitled people's self‐promoting values motivate hierarchy‐restoring retribution\", published in the European Journal of Social Psychology, by Liz Redford and Kate A. Ratliff.",
#     "fork": false,
#     "url": "https://api.github.com/repos/lizre/psychological-entitlement-justice",
#     "forks_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/forks",
#     "keys_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/keys{/key_id}",
#     "collaborators_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/collaborators{/collaborator}",
#     "teams_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/teams",
#     "hooks_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/hooks",
#     "issue_events_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/issues/events{/number}",
#     "events_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/events",
#     "assignees_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/assignees{/user}",
#     "branches_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/branches{/branch}",
#     "tags_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/tags",
#     "blobs_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/git/blobs{/sha}",
#     "git_tags_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/git/tags{/sha}",
#     "git_refs_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/git/refs{/sha}",
#     "trees_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/git/trees{/sha}",
#     "statuses_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/statuses/{sha}",
#     "languages_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/languages",
#     "stargazers_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/stargazers",
#     "contributors_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/contributors",
#     "subscribers_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/subscribers",
#     "subscription_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/subscription",
#     "commits_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/commits{/sha}",
#     "git_commits_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/git/commits{/sha}",
#     "comments_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/comments{/number}",
#     "issue_comment_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/issues/comments{/number}",
#     "contents_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/contents/{+path}",
#     "compare_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/compare/{base}...{head}",
#     "merges_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/merges",
#     "archive_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/{archive_format}{/ref}",
#     "downloads_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/downloads",
#     "issues_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/issues{/number}",
#     "pulls_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/pulls{/number}",
#     "milestones_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/milestones{/number}",
#     "notifications_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/notifications{?since,all,participating}",
#     "labels_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/labels{/name}",
#     "releases_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/releases{/id}",
#     "deployments_url": "https://api.github.com/repos/lizre/psychological-entitlement-justice/deployments",
#     "created_at": "2018-07-19T17:49:18Z",
#     "updated_at": "2018-07-20T14:57:21Z",
#     "pushed_at": "2018-07-20T14:57:20Z",
#     "git_url": "git://github.com/lizre/psychological-entitlement-justice.git",
#     "ssh_url": "git@github.com:lizre/psychological-entitlement-justice.git",
#     "clone_url": "https://github.com/lizre/psychological-entitlement-justice.git",
#     "svn_url": "https://github.com/lizre/psychological-entitlement-justice",
#     "homepage": "",
#     "size": 1731,
#     "stargazers_count": 0,
#     "watchers_count": 0,
#     "language": "Scheme",
#     "has_issues": true,
#     "has_projects": true,
#     "has_downloads": true,
#     "has_wiki": true,
#     "has_pages": false,
#     "has_discussions": false,
#     "forks_count": 0,
#     "mirror_url": null,
#     "archived": false,
#     "disabled": false,
#     "open_issues_count": 0,
#     "license": null,
#     "allow_forking": true,
#     "is_template": false,
#     "web_commit_signoff_required": false,
#     "topics": [
#
#     ],
#     "visibility": "public",
#     "forks": 0,
#     "open_issues": 0,
#     "watchers": 0,
#     "default_branch": "master",
#     "permissions": {
#       "admin": true,
#       "maintain": true,
#       "push": true,
#       "triage": true,
#       "pull": true
#     }
#   },
#   {
#     "id": 141613119,
#     "node_id": "MDEwOlJlcG9zaXRvcnkxNDE2MTMxMTk=",
#     "name": "social-status-justice",
#     "full_name": "lizre/social-status-justice",
#     "private": false,
#     "owner": {
#       "login": "lizre",
#       "id": 38010821,
#       "node_id": "MDQ6VXNlcjM4MDEwODIx",
#       "avatar_url": "https://avatars.githubusercontent.com/u/38010821?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/lizre",
#       "html_url": "https://github.com/lizre",
#       "followers_url": "https://api.github.com/users/lizre/followers",
#       "following_url": "https://api.github.com/users/lizre/following{/other_user}",
#       "gists_url": "https://api.github.com/users/lizre/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/lizre/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/lizre/subscriptions",
#       "organizations_url": "https://api.github.com/users/lizre/orgs",
#       "repos_url": "https://api.github.com/users/lizre/repos",
#       "events_url": "https://api.github.com/users/lizre/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/lizre/received_events",
#       "type": "User",
#       "site_admin": true
#     },
#     "html_url": "https://github.com/lizre/social-status-justice",
#     "description": "Data and SPSS syntax for empirical paper, \"Retribution as hierarchy regulation: Hierarchy preferences moderate the effect of offender socioeconomic status on support for retribution\", published in The British Journal of Social Psychology, by Liz Redford and Kate A. Ratliff.",
#     "fork": false,
#     "url": "https://api.github.com/repos/lizre/social-status-justice",
#     "forks_url": "https://api.github.com/repos/lizre/social-status-justice/forks",
#     "keys_url": "https://api.github.com/repos/lizre/social-status-justice/keys{/key_id}",
#     "collaborators_url": "https://api.github.com/repos/lizre/social-status-justice/collaborators{/collaborator}",
#     "teams_url": "https://api.github.com/repos/lizre/social-status-justice/teams",
#     "hooks_url": "https://api.github.com/repos/lizre/social-status-justice/hooks",
#     "issue_events_url": "https://api.github.com/repos/lizre/social-status-justice/issues/events{/number}",
#     "events_url": "https://api.github.com/repos/lizre/social-status-justice/events",
#     "assignees_url": "https://api.github.com/repos/lizre/social-status-justice/assignees{/user}",
#     "branches_url": "https://api.github.com/repos/lizre/social-status-justice/branches{/branch}",
#     "tags_url": "https://api.github.com/repos/lizre/social-status-justice/tags",
#     "blobs_url": "https://api.github.com/repos/lizre/social-status-justice/git/blobs{/sha}",
#     "git_tags_url": "https://api.github.com/repos/lizre/social-status-justice/git/tags{/sha}",
#     "git_refs_url": "https://api.github.com/repos/lizre/social-status-justice/git/refs{/sha}",
#     "trees_url": "https://api.github.com/repos/lizre/social-status-justice/git/trees{/sha}",
#     "statuses_url": "https://api.github.com/repos/lizre/social-status-justice/statuses/{sha}",
#     "languages_url": "https://api.github.com/repos/lizre/social-status-justice/languages",
#     "stargazers_url": "https://api.github.com/repos/lizre/social-status-justice/stargazers",
#     "contributors_url": "https://api.github.com/repos/lizre/social-status-justice/contributors",
#     "subscribers_url": "https://api.github.com/repos/lizre/social-status-justice/subscribers",
#     "subscription_url": "https://api.github.com/repos/lizre/social-status-justice/subscription",
#     "commits_url": "https://api.github.com/repos/lizre/social-status-justice/commits{/sha}",
#     "git_commits_url": "https://api.github.com/repos/lizre/social-status-justice/git/commits{/sha}",
#     "comments_url": "https://api.github.com/repos/lizre/social-status-justice/comments{/number}",
#     "issue_comment_url": "https://api.github.com/repos/lizre/social-status-justice/issues/comments{/number}",
#     "contents_url": "https://api.github.com/repos/lizre/social-status-justice/contents/{+path}",
#     "compare_url": "https://api.github.com/repos/lizre/social-status-justice/compare/{base}...{head}",
#     "merges_url": "https://api.github.com/repos/lizre/social-status-justice/merges",
#     "archive_url": "https://api.github.com/repos/lizre/social-status-justice/{archive_format}{/ref}",
#     "downloads_url": "https://api.github.com/repos/lizre/social-status-justice/downloads",
#     "issues_url": "https://api.github.com/repos/lizre/social-status-justice/issues{/number}",
#     "pulls_url": "https://api.github.com/repos/lizre/social-status-justice/pulls{/number}",
#     "milestones_url": "https://api.github.com/repos/lizre/social-status-justice/milestones{/number}",
#     "notifications_url": "https://api.github.com/repos/lizre/social-status-justice/notifications{?since,all,participating}",
#     "labels_url": "https://api.github.com/repos/lizre/social-status-justice/labels{/name}",
#     "releases_url": "https://api.github.com/repos/lizre/social-status-justice/releases{/id}",
#     "deployments_url": "https://api.github.com/repos/lizre/social-status-justice/deployments",
#     "created_at": "2018-07-19T17:48:29Z",
#     "updated_at": "2018-07-20T14:57:25Z",
#     "pushed_at": "2018-07-20T14:57:23Z",
#     "git_url": "git://github.com/lizre/social-status-justice.git",
#     "ssh_url": "git@github.com:lizre/social-status-justice.git",
#     "clone_url": "https://github.com/lizre/social-status-justice.git",
#     "svn_url": "https://github.com/lizre/social-status-justice",
#     "homepage": "",
#     "size": 2864,
#     "stargazers_count": 0,
#     "watchers_count": 0,
#     "language": "Scheme",
#     "has_issues": true,
#     "has_projects": true,
#     "has_downloads": true,
#     "has_wiki": true,
#     "has_pages": false,
#     "has_discussions": false,
#     "forks_count": 0,
#     "mirror_url": null,
#     "archived": false,
#     "disabled": false,
#     "open_issues_count": 0,
#     "license": null,
#     "allow_forking": true,
#     "is_template": false,
#     "web_commit_signoff_required": false,
#     "topics": [
#
#     ],
#     "visibility": "public",
#     "forks": 0,
#     "open_issues": 0,
#     "watchers": 0,
#     "default_branch": "master",
#     "permissions": {
#       "admin": true,
#       "maintain": true,
#       "push": true,
#       "triage": true,
#       "pull": true
#     }
#   }
# ]

# %% [markdown]
# In python:

# %%
headers = {
    "Accept": "application/vnd.github+json",
    "Authorization": "Bearer <YOUR-TOKEN>",
    "X-GitHub-Api-Version": "2022-11-28",
}

requests.get("https://api.github.com/users/lizre/repos", headers=headers)
# Out:
# <Response [200]>

# %% [markdown]
# # Handling responses

# %% [markdown]
# ### Status codes

# %% [markdown]
# - `200`: OK. The request was successful.
# - `201`: Created. The request was successful and a resource was created as a result. This is typically the response sent after POST requests.
# - `204`: No Content. The request was successful, but there's no representation to return (i.e. the response is empty).
# - `400`: Bad Request. The request could not be understood or was missing required parameters.
# - `401`: Unauthorized. Authentication failed or was not provided.
# - `403`: Forbidden. Authentication succeeded but the authenticated user does not have access to the requested resource.
# - `404`: Not Found. The requested resource could not be found.
# - `405`: Method Not Allowed. The method or verb used by the request is not allowed.
# - `500`: Internal Server Error. An error occurred in the server.

# %% [markdown]
# ### `requests` exceptions

# %% [markdown]
# requests.exceptions.RequestException: This is the base exception class for requests. All other requests exceptions inherit from this one. It's a catch-all exception for when something goes wrong.
#
# requests.exceptions.ConnectionError: Raised when a network problem occurs, like a DNS resolution failure, refused connection, etc.
#
# requests.exceptions.HTTPError: Raised when an HTTP error occurs. You can call Response.raise_for_status() to throw this error if the HTTP request returned an unsuccessful status code.
#
# requests.exceptions.Timeout: Raised when a request times out.
#
# requests.exceptions.TooManyRedirects: Raised when a request exceeds the configured number of maximum redirections.

# %%
# !curl https://api.github.com/users/lizre/learn-py

# %%
response = requests.post(
                        "https://httpbin.org/post" # A simple HTTP Request & Response Service.
                        , data = {'name': 'me', 'email': 'me@example.com'}
                        )

response.json()

# %%
print(response.headers)
response.headers['Server']

# %% [markdown]
# for no good reason, the developers of the "requests" package chose to make `response` only return the status code:

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# # What is json

# %% [markdown]
# - JavaScript Object Notation
# - language independent
# - use https://jsonlint.com/ to validate format

# %% [markdown]
# # JSON string vs native JSON object

# %% [markdown]
# ### JSON string
# a string representation of a JSON object, formatted according to the JSON (JavaScript Object Notation) standard.
#
# See the quotes (`'`) around it?

# %%
response.text
# Out:
# '{"login":"lizre","id":38010821,"node_id":"MDQ6VXNlcjM4MDEwODIx","avatar_url":"https://avatars.githubusercontent.com/u/38010821?v=4","gravatar_id":"","url":"https://api.github.com/users/lizre","html_url":"https://github.com/lizre","followers_url":"https://api.github.com/users/lizre/followers","following_url":"https://api.github.com/users/lizre/following{/other_user}","gists_url":"https://api.github.com/users/lizre/gists{/gist_id}","starred_url":"https://api.github.com/users/lizre/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/lizre/subscriptions","organizations_url":"https://api.github.com/users/lizre/orgs","repos_url":"https://api.github.com/users/lizre/repos","events_url":"https://api.github.com/users/lizre/events{/privacy}","received_events_url":"https://api.github.com/users/lizre/received_events","type":"User","site_admin":true,"name":"lizzie redford","company":null,"blog":"lizredford.weebly.com","location":"Florida, USA","email":null,"hireable":null,"bio":null,"twitter_username":null,"public_repos":18,"public_gists":0,"followers":17,"following":23,"created_at":"2018-04-02T15:50:27Z","updated_at":"2023-11-09T20:16:03Z"}'

# %%
type(response.text)
# Out:
# str

# %% [markdown]
# ### Native JavaScript object
# - an instance of the Object data type in JavaScript.
# - a collection of properties, where each property is a key-value pair.
# - Keys are always strings, and values can be any data type.

# %%
response.json()
# Out:
# {'login': 'lizre',
#  'id': 38010821,
#  'node_id': 'MDQ6VXNlcjM4MDEwODIx',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/38010821?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/lizre',
#  'html_url': 'https://github.com/lizre',
#  'followers_url': 'https://api.github.com/users/lizre/followers',
#  'following_url': 'https://api.github.com/users/lizre/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/lizre/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/lizre/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/lizre/subscriptions',
#  'organizations_url': 'https://api.github.com/users/lizre/orgs',
#  'repos_url': 'https://api.github.com/users/lizre/repos',
#  'events_url': 'https://api.github.com/users/lizre/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/lizre/received_events',
#  'type': 'User',
#  'site_admin': True,
#  'name': 'lizzie redford',
#  'company': None,
#  'blog': 'lizredford.weebly.com',
#  'location': 'Florida, USA',
#  'email': None,
#  'hireable': None,
#  'bio': None,
#  'twitter_username': None,
#  'public_repos': 18,
#  'public_gists': 0,
#  'followers': 17,
#  'following': 23,
#  'created_at': '2018-04-02T15:50:27Z',
#  'updated_at': '2023-11-09T20:16:03Z'}

# %% [markdown]
# ### Wait, isnt that just a dictionary?

# %% [markdown]
# Yes!

# %%
type(response.json())
# Out:
# dict

# %% [markdown]
# `response.json()` method in `requests` library parses the response and converts it into a Python data structure, typically a dictionary (or a list if the JSON data is an array.

# %% [markdown]
# ### JSON is the only format you can actually work with / access pieces of.
#
# #### In two ways:

# %%
response.headers['Content-Type']
# Out:
# 'application/json; charset=utf-8'

# %% [markdown]
# will raise a KeyError if the 'Content-Type' header is not present in the response.

# %%
response.headers.get('Content-Type')
# Out:
# 'application/json; charset=utf-8'

# %% [markdown]
# will return None if the 'Content-Type' header is not present.

# %% [markdown]
# #### You can't access parts of it when it's a string:

# %%
response.text.get('login')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 response.text.get('login')
#
# AttributeError: 'str' object has no attribute 'get'

# %%
response.text['login']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 response.text['login']
#
# TypeError: string indices must be integers, not 'str'

# %% [markdown]
# ### If can't access pieces of string, why use string at all?
#
# the reason is so it can be transmitted across the network in a http request.
# - APIs can only transmit a byte representation of a string.
# - this is because bytes are universal, efficient, simple and compatible. json is not. also non-text (like images) can only be as bytes.

# %% [markdown]
# That's why you also get the response as _bytes_:

# %%
response.content
# Out:
# b'{"login":"lizre","id":38010821,"node_id":"MDQ6VXNlcjM4MDEwODIx","avatar_url":"https://avatars.githubusercontent.com/u/38010821?v=4","gravatar_id":"","url":"https://api.github.com/users/lizre","html_url":"https://github.com/lizre","followers_url":"https://api.github.com/users/lizre/followers","following_url":"https://api.github.com/users/lizre/following{/other_user}","gists_url":"https://api.github.com/users/lizre/gists{/gist_id}","starred_url":"https://api.github.com/users/lizre/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/lizre/subscriptions","organizations_url":"https://api.github.com/users/lizre/orgs","repos_url":"https://api.github.com/users/lizre/repos","events_url":"https://api.github.com/users/lizre/events{/privacy}","received_events_url":"https://api.github.com/users/lizre/received_events","type":"User","site_admin":true,"name":"lizzie redford","company":null,"blog":"lizredford.weebly.com","location":"Florida, USA","email":null,"hireable":null,"bio":null,"twitter_username":null,"public_repos":18,"public_gists":0,"followers":17,"following":23,"created_at":"2018-04-02T15:50:27Z","updated_at":"2023-11-09T20:16:03Z"}'

# %% [markdown]
# ### You need to work with byte format if you _stream_

# %% [markdown]
# - If you _stream_ an http response, you will _only_ get bytes, not string or json.
# - You would stream if you want _chunks_ as they become available, instead of waiting for the complete response.

# %%
response = requests.get(url = "https://api.github.com/users/lizre", stream = True)
response
# Out:
# <Response [200]>

# %% [markdown]
# #### How to get chunks, formatted as bytes, back to string?
#
# utf-8 (Unicode Transformation Format - 8-bit) translates between characters and bytes:

# %%
response.content.decode("utf-8")
# Out:
# '{"login":"lizre","id":38010821,"node_id":"MDQ6VXNlcjM4MDEwODIx","avatar_url":"https://avatars.githubusercontent.com/u/38010821?v=4","gravatar_id":"","url":"https://api.github.com/users/lizre","html_url":"https://github.com/lizre","followers_url":"https://api.github.com/users/lizre/followers","following_url":"https://api.github.com/users/lizre/following{/other_user}","gists_url":"https://api.github.com/users/lizre/gists{/gist_id}","starred_url":"https://api.github.com/users/lizre/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/lizre/subscriptions","organizations_url":"https://api.github.com/users/lizre/orgs","repos_url":"https://api.github.com/users/lizre/repos","events_url":"https://api.github.com/users/lizre/events{/privacy}","received_events_url":"https://api.github.com/users/lizre/received_events","type":"User","site_admin":true,"name":"lizzie redford","company":null,"blog":"lizredford.weebly.com","location":"Florida, USA","email":null,"hireable":null,"bio":null,"twitter_username":null,"public_repos":18,"public_gists":0,"followers":17,"following":23,"created_at":"2018-04-02T15:50:27Z","updated_at":"2023-11-09T20:16:03Z"}'

# %% [markdown]
# # So strings are for transmission, JSON is for using and accessing values, and bytes are for streaming. How to converting between them?

# %% [markdown]
# String to a native object: deserialization
#
# JSON string to a dictionary using json.loads().

# %% [markdown]
# Native object to a string: serialization or stringification.

# %%
json.dumps()

# %% [markdown]
# when converting to json you can get `Jsondecodeerror`

# %%
Jsondecodeerror: Expecting value: line 1 column 2 (chaar 2) is when json decoder is excpecting a value for a key but not finding it.but usually means you dont actually have json.
Like “[DONE]” will throw, even tho no key, not just no value.
 Json dumps vs loads and get and response.text
Response.content is as bytes, like for images

# %% [markdown]
# # Misc

# %% [markdown]
# # Reading jsonl file

# %%
import json

json_data = []
with open('json_data.jsonl', 'r') as f:
    for line in f:
        json_data.append(json.loads(line))

# %%
lines = response.text.splitlines()

for line in lines:
    if line.startswith('data: ') and "[DONE]" not in line and "finish_reason" in line:
        json_str = line[5:]  # Remove 'data: ' prefix; its irrelevant and cant be parsed as json
        json_obj = json.loads(json_str) # make the string be json
        finish_reason = choice.get("finish_reason", "")
        print(finish_reason)
